# %%
v="4"
print(type(v))
# Out:
# <class 'str'>

# %%
import sys
a= 12.67
print("variable Name",a)
print("variable Name", type(a))
print(sys.getsizeof(a), "bytes")
# Out:
# variable Name 12.67
# variable Name <class 'float'>
# 24 bytes

# %% [raw]
# print("variable Name")

# %%
print("variable Name","a", "----", "45")
# Out:
# variable Name a ---- 45

# %%
print("name :", "moresh","abc", end="#")
# Out:
# name : moresh abc#

# %%
print("name :", "moresh","abc", sep="&")
# Out:
# name :&moresh&abc

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
print(a)
# Out:
# 12.67

# %%
# complex
d=14+13j
print("variable Name",d)
print("variable Name",type(d))
# Out:
# variable Name (14+13j)
# variable Name <class 'complex'>

# %%
# list
ls=[1,2,3,]
print(type(ls))
# Out:
# <class 'list'>

# %%
# set
d={1,1,1,"dict"}
print("variable Name",d)
print("variable Name",type(d))
# Out:
# variable Name {1, 'dict'}
# variable Name <class 'set'>

# %%
# tuple
d=(1,12.5,"3j","dict")
print("variable Name",d)
print("variable Name",type(d))
# Out:
# variable Name (1, 12.5, '3j', 'dict')
# variable Name <class 'tuple'>

# %%
Name=input("Enter your name")
print("My Name is",Name)
# Out:
# My Name is
