# %%
Name=input("Enter your name")
print("My Name is",Name)

# %%
# operatos:
# it is used to perform any operation arithemetic or logica etc on one or many variables
# arithemetic : +,-,*,%,//,**
# comarision : ==,!=,>=,<=,>,< ===
# logical : and,or,not
# assignment: =, +=, -=, *=, etc..
# membership : in, notin
# identity : is, isnot

# %%
# arthemetic operators :
a=17
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 20
# 14
# 51
# 5.666666666666667
# 2
# 4913
# 5

# %%
# comparision operators :
a=56
b=23
print(a==b) 
print(a!=b)
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
# 3. logical operators :
a=True
b=False
# 1. and
print(a and b)
print(a and True)
print(a and False)
print(False and True)
# 2. OR
# print(a or b)
# print(a or True)
# print(a or False)
# print(False or True)
# 3. not
# print(not a)
# print(not b)
# Out:
# False
# True
# False
# False

# %%
# 0 = false
# numerical value = true
print(3 and 0)
print(0 and 5)
print(6 and 5)
# Out:
# 0
# 0
# 5
# 0

# %%
# 4. assignment
# 1.+=
# a=3
# a+=3
# a=a+3
# print(a)
# 2. -=
# a-=3
# print(a)
# 3. *=
a=4.4
a*=3
print(a)
# 4. /=
a=3
a/=3
print(a)
# 5. //=
a=4
a//=3
print(a)
# Out:
# 13.200000000000001
# 1.0
# 1

# %%
# conditional statement(control flow)
# condition statement allows you to excute perticular block of based on their condition
# types: 
# 1. single if
# 2. if else
# 3 elif

# %%
# single if
age=20
if age>18:
    print("You can Vote")
    print("Code excuted")

# %%
age=24
graduation='Done'
if age>18 :
    if graduation == 'Done':
    print("you are eligible for placement drive")
print("code excute")
# Out:
#   Cell In[8], line 5
#     print("you are eligible for placement drive")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
age = input("enter the age")
if age>20:
    print("you can drive a plain")
# Out:
# enter the age 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 age=input("enter the age")
# ----> 2 if age>20:
#       3     print("you can drive a plain")
#
# TypeError: '>' not supported between instances of 'str' and 'int'
